# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## <center> Quantitative Finance S. 2022 <center/>
# ## <center> Professor José Mario Zárate <center/>
# ### <center> Homework 6.1 <center/>
#
# ### <center> Díaz Verduzco Alexia Marisol IF720500 <center/>
# ### <center> González Reyes Christian Eduardo IF721850 <center/>
# ### <center> López Lazareno Diego Alberto IF722100 <center/>
# ### <center> Romero Riggen Santiago IF715099 <center/>

# %% [markdown]
# ## Homework 6.1

# %%
# Required libraries
import yfinance as yf
import pandas as pd 
import numpy as np 
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# *Reminding Taylor Series for two variables*
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Using taylor series solve in detail (a = 0,b = 0 and k = 2)
# ###### 1)  $f(x,y) = e^{(xy)} + x^2y^2+5$

# %% [markdown]
# *Getting partial derivatives*
#
# $f(0,0) = e^{((0)(0))} + (0)^2(0)^2+5$
#
# $f(0,0) = 1 + 5 = 6$
#
# $\frac{\partial f}{\partial x} = ye^{xy} + 2xy^2 = 0 $
#
# $\frac{\partial f}{\partial y} = xe^{xy} + 2x^2y = 0 $
#
# $\frac{\partial^{2} f}{\partial x^{2}} = y^2e^{xy} + 2y^2 = 0$
#
# $\frac{\partial^{2} f}{\partial y^{2}} = x^2e^{xy} + 2x^2 = 0 $
#
# $\frac{\partial^{2} f}{\partial x \partial y} = e^{xy} + xye^{xy} + 4xy = 1 $
#
#
# $\frac{\partial^{2} f}{\partial y \partial x} = e^{xy} + xye^{xy} + 4xy = 1$

# %% [markdown]
# *Replacing in Taylor Series*
#
# $f(x,y) = 6 + 0 (x-0) + 0(y-0)+ \frac{1}{2} [0(x-0)^2 +0(y-0)^2 + 1(x-0)(y-0)+1(y-0)(x-0)]$
#
# $f(x,y) = 6 + \frac{1}{2} [1(x)(y)+1(y)(x)]$
#
# $f(x,y) = 6 + \frac{1}{2}[xy+yx]$
#
# $f(x,y) = 6 + \frac{1}{2}[2xy]$
#
# $f(x,y) = 6 + xy$

# %% [markdown]
# #### 2) Let’s consider certain diffusion process dXt = Xt σdWt find a differential form of a function
# #####  $f(X_{(t+\triangle t)},t+ \triangle t) = df_{(t+\triangle t)} : = df_t$

# %% [markdown]
# $f(x,y) = f(S,t)$
#
# $x = S_i$
# $y = t_i$
#
# $f(S,t) = f(S,t) + \frac{\partial f(S,t)}{\partial S} (S-S_i) + \frac{\partial f(S,t)}{\partial t}(t-t_i) + \frac{1}{2!}[\frac{\partial^2 f(S,t)}{\partial S^2} (S- S_i)^2+\frac{\partial^2 f(S,t)}{\partial^2 t}(t-t_i)^2 + \frac{\partial^2 f(S,t)}{\partial S \partial t} (S- S_i)(t-t_i) + \frac{\partial^2 f(S,t)}{\partial t  \partial S} (t-t_i) (S- S_i)] $
#
# $ df = 0  + \frac{\partial f(S,t)}{\partial S} dS^2 + \frac{\partial f(S,t)}{\partial t} dt + \frac{1}{2} [\frac{\partial^2 f(S,t)}{\partial S^2} (dS)^2  + \frac{\partial^2 f(S,t)}{\partial^2 t} (dt)^2 + \frac{\partial^2 f(S,t)}{\partial S \partial t}(dS)(dt) + \frac{\partial^2 f(S,t)}{\partial t  \partial S} (dt)(dS)] $
#
# *Removal by ITÔ* ![image.png](attachment:image.png)
#
# $df = \frac{\partial f(S,t)}{\partial S} dS + \frac{\partial f(S,t)}{\partial t} dt + \frac{1}{2}[\frac{\partial^2 f(S,t)}{\partial S^2} ( \mu S_t dt + S_t \sigma dW_t)^2]$
#
# $df = \frac{\partial f(S,t)}{\partial S} dS + \frac{\partial f(S,t)}{\partial t} dt + \frac{1}{2}\frac{\partial^2 f(S,t)}{\partial S^2} S_t^2 \sigma^2 dt$

# %% [markdown]
# #### 3) Let’s consider certain diffusion process $dX_t = \mu S^{3}_t + \sigma^2dW_t + \frac{1}{2}dt$ find a differential form of a function $f(X_{(t+\triangle t)},t+ \triangle t) = df_{(t+\triangle t)} : = df_t=$
